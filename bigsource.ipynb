# %%
# %matplotlib inline

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
from gammapy.irf import load_cta_irfs
from gammapy.maps import WcsGeom, MapAxis
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    GaussianSpatialModel,
    SkyModel,
    Models,
    FoVBackgroundModel,
)
from gammapy.makers import MapDatasetMaker, SafeMaskMaker
from gammapy.modeling import Fit
from gammapy.datasets import Datasets, MapDataset
from gammapy.data import Observation, observatory_locations
from regions import CircleSkyRegion
from scipy.stats import chi2, norm

import matplotlib.pyplot as plt
from IPython.display import display
from gammapy.analysis import Analysis, AnalysisConfig
from gammapy.estimators import ExcessMapEstimator, FluxPointsEstimator
from gammapy.modeling import Fit
from gammapy.catalog import CATALOG_REGISTRY, SourceCatalogHGPS

# %%
# !gammapy info --no-envvar --no-dependencies --no-system
# Out:
# Gammapy package:
#
# 	version                : 0.20.1
# 	path                   : D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy

# %%
print(CATALOG_REGISTRY)
catalog=SourceCatalogHGPS()
source = catalog[3]

model_simu = source.sky_model()
print(model_simu)
# Out:
# Registry
# --------
#
# SourceCatalogGammaCat: gamma-cat
# SourceCatalogHGPS    : hgps
# SourceCatalog2HWC    : 2hwc
# SourceCatalog3FGL    : 3fgl
# SourceCatalog4FGL    : 4fgl
# SourceCatalog2FHL    : 2fhl
# SourceCatalog3FHL    : 3fhl
# SourceCatalog3HWC    : 3hwc
#
# SkyModel
#
#   Name                      : HESS J1018-589 B
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      2.196   +/-    0.09
#     amplitude                     :   9.15e-14   +/- 1.1e-14 1 / (cm2 s TeV)
#     reference             (frozen):      2.742       TeV
#     lon_0                         :    284.223   +/-    0.04 deg
#     lat_0                         :     -1.772   +/-    0.03 deg
#     sigma                         :      0.150   +/-    0.03 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg

# %%
# Loading IRFs
irfs = load_cta_irfs(
    "$GAMMAPY_DATA/cta-1dc/caldb/data/cta/1dc/bcf/South_z20_50h/irf_file.fits"
)
# Out:
# Invalid unit found in background table! Assuming (s-1 MeV-1 sr-1)

# %%
print(irfs)
# Out:
# {'aeff': <gammapy.irf.effective_area.EffectiveAreaTable2D object at 0x000001FEC5A67FD0>, 'bkg': <gammapy.irf.background.Background3D object at 0x000001FEC06BCDC0>, 'edisp': <gammapy.irf.edisp.core.EnergyDispersion2D object at 0x000001FEC5A67EB0>, 'psf': <gammapy.irf.psf.parametric.EnergyDependentMultiGaussPSF object at 0x000001FEC1362100>}

# %%
irfs["aeff"].peek()
irfs["bkg"].peek()
irfs["edisp"].peek()
irfs["psf"].peek()

# %%
# Define the observation parameters (typically the observation duration and the pointing position):
livetime = 6.0*u.hr
pointing = SkyCoord(283, 0, unit="deg", frame="galactic")

# %%
# Define map geometry for binned simulation
energy_reco = MapAxis.from_edges(
    np.logspace(-1.0, 1.0, 10), unit="TeV", name="energy", interp="log"
)
geom = WcsGeom.create(
    skydir=(283, 0),
    binsz=0.02,
    width=(6, 6),
    frame="galactic",
    axes=[energy_reco],
)
# It is usually useful to have a separate binning for the true energy axis
energy_true = MapAxis.from_edges(
    np.logspace(-1.5, 1.5, 30), unit="TeV", name="energy_true", interp="log"
)

empty = MapDataset.create(
    geom, name="dataset-simu", energy_axis_true=energy_true
)

# %%
# Create an in-memory observation
location = observatory_locations["cta_south"]
obs = Observation.create(
    pointing=pointing, livetime=livetime, irfs=irfs, location=location
)
print(obs)
# Out:
# Observation
#
# 	obs id            : 0
#  	tstart            : 51544.00
# 	tstop             : 51544.25
# 	duration          : 21600.00 s
# 	pointing (icrs)   : 154.4 deg, -56.8 deg
#
# 	deadtime fraction : 0.0%

# %%
# Make the MapDataset
maker = MapDatasetMaker(selection=["exposure", "background", "psf", "edisp"])

maker_safe_mask = SafeMaskMaker(methods=["offset-max"], offset_max=4.0 * u.deg)

# %%
bkg_model = FoVBackgroundModel(dataset_name="dataset-simu")
#bkg_model.spectral_model.norm.value = np.random.normal(1,0.1)
#bkg_model.spectral_model.tilt.value = np.random.normal(0,0.05)
model_simu.parameters["sigma"].value= 3
Models([bkg_model, model_simu]).parameters.to_table()
# Out:
# <Table length=11>
#   type      name      value         unit      ...    max    frozen is_norm link
#   str8      str9     float64       str14      ...  float64   bool    bool  str1
# -------- --------- ----------- -------------- ... --------- ------ ------- ----
# spectral      norm  1.0000e+00                ...       nan  False    True
# spectral      tilt  0.0000e+00                ...       nan   True   False
# spectral reference  1.0000e+00            TeV ...       nan   True   False
# spectral     index  2.1959e+00                ...       nan  False   False
# spectral amplitude  9.1545e-14 cm-2 s-1 TeV-1 ...       nan  False    True
# spectral reference  2.7416e+00            TeV ...       nan   True   False
#  spatial     lon_0  2.8422e+02            deg ...       nan  False   False
#  spatial     lat_0 -1.7716e+00            deg ... 9.000e+01  False   False
#  spatial     sigma  3.0000e+00            deg ...       nan  False   False
#  spatial         e  0.0000e+00                ... 1.000e+00   True   False
#  spatial       phi  0.0000e+00            deg ...       nan   True   False

# %%
dataset = maker.run(empty, obs)
dataset = maker_safe_mask.run(dataset, obs)

dataset.models =  Models([bkg_model, model_simu])
dataset.fake()
# -- like an observation
dataset.models =  Models([bkg_model])    
fit = Fit(optimize_opts={"print_level": 1})
result = fit.run(datasets=dataset)
L0 = result.total_stat
print(L0)

model = model_simu.copy(name="model_fit")
model.parameters["lon_0"].min=280.5
model.parameters["lon_0"].max=285.5
model.parameters["lat_0"].min=-2.5
model.parameters["lat_0"].max=2.5
dataset.models = Models([bkg_model, model])
fit = Fit(optimize_opts={"print_level": 1})
result = fit.run(datasets=dataset)
L1 = result.total_stat
print(L1)
TS=L0-L1
# Out:
# 614758.0193594478
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder Matrix not pos.def, gdel = 40.3735 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -2.90559e-05
# W MnPosDef non-positive diagonal element in covariance matrix[ 1 ] = -9.67463
# W MnPosDef non-positive diagonal element in covariance matrix[ 2 ] = -32864.3
# W MnPosDef non-positive diagonal element in covariance matrix[ 3 ] = -1.45675
# W MnPosDef non-positive diagonal element in covariance matrix[ 4 ] = -167.157
# W MnPosDef non-positive diagonal element in covariance matrix[ 5 ] = -57.9078
# W MnPosDef Added to diagonal of Error matrix a value 32864.8
# W MnPosDef Matrix forced pos-def by adding to diagonal 20.8129
# W VariableMetricBuilder gdel = -3.02796e+09
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: invalid value encountered in subtract
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: invalid value encountered in subtract
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: invalid value encountered in subtract
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: invalid value encountered in subtract
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: invalid value encountered in subtract
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: invalid value encountered in subtract
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\units\quantity.py:613: RuntimeWarning: invalid value encountered in subtract
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 145458 Requested 0.0002
# W MnPosDef non-positive diagonal element in covariance matrix[ 5 ] = -2.68994
# W MnPosDef Added to diagonal of Error matrix a value 3.18994
# W MnPosDef Matrix forced pos-def by adding to diagonal 4431.48
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 0.390458 Requested 0.0002
# W VariableMetricBuilder FunctionMinimum is invalid after second try
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.241168
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.594951 > 0
# W MnPosDef Matrix forced pos-def by adding to diagonal 11.8898
# W VariableMetricBuilder gdel = -30.4128
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 10.4522 Requested 0.0002
# W VariableMetricBuilder FunctionMinimum is invalid after second try
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 15.0968 Requested 0.0002
# W VariableMetricBuilder No convergence; Edm 15.0968 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder Matrix not pos.def, gdel = 8.15672 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 5 ] = -0.165565
# W MnPosDef Added to diagonal of Error matrix a value 0.665566
# W VariableMetricBuilder gdel = -6982.39
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 20>()
#      18 dataset.models = Models([bkg_model, model])
#      19 fit = Fit(optimize_opts={"print_level": 1})
# ---> 20 result = fit.run(datasets=dataset)
#      21 L1 = result.total_stat
#      22 print(L1)
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\modeling\fit.py:158, in Fit.run(self, datasets)
#     145 def run(self, datasets):
#     146     """Run all fitting steps.
#     147
#     148     Parameters
#    (...)
#     156         Fit result
#     157     """
# --> 158     optimize_result = self.optimize(datasets=datasets)
#     160     if self.backend not in registry.register["covariance"]:
#     161         log.warning("No covariance estimate - not supported by this backend.")
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\modeling\fit.py:199, in Fit.optimize(self, datasets)
#     195 compute = registry.get("optimize", backend)
#     196 # TODO: change this calling interface!
#     197 # probably should pass a fit statistic, which has a model, which has parameters
#     198 # and return something simpler, not a tuple of three things
# --> 199 factors, info, optimizer = compute(
#     200     parameters=parameters,
#     201     function=datasets.stat_sum,
#     202     store_trace=self.store_trace,
#     203     **kwargs,
#     204 )
#     206 if backend == "minuit":
#     207     self._minuit = optimizer
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\modeling\iminuit.py:79, in optimize_iminuit(parameters, function, store_trace, **kwargs)
#      73 migrad_opts = kwargs.pop("migrad_opts", {})
#      75 minuit, minuit_func = setup_iminuit(
#      76     parameters=parameters, function=function, store_trace=store_trace, **kwargs
#      77 )
# ---> 79 minuit.migrad(**migrad_opts)
#      81 factors = minuit.values
#      82 info = {
#      83     "success": minuit.valid,
#      84     "nfev": minuit.nfcn,
#      85     "message": _get_message(minuit, parameters),
#      86     "trace": minuit_func.trace,
#      87 }
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\iminuit\minuit.py:686, in Minuit.migrad(self, ncall, iterate)
#     684 if self._precision is not None:
#     685     migrad.precision = self._precision
# --> 686 fm = migrad(ncall, self._tolerance)
#     687 if fm.is_valid or fm.has_reached_call_limit:
#     688     break
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\modeling\iminuit.py:25, in MinuitLikelihood.fcn(self, *factors)
#      22 def fcn(self, *factors):
#      23     self.parameters.set_parameter_factors(factors)
# ---> 25     total_stat = self.function()
#      27     if self.store_trace:
#      28         self.store_trace_iteration(total_stat)
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\core.py:224, in Datasets.stat_sum(self)
#     222 # TODO: add parallel evaluation of likelihoods
#     223 for dataset in self:
# --> 224     stat_sum += dataset.stat_sum()
#     225 return stat_sum
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\map.py:1065, in MapDataset.stat_sum(self)
#    1063 def stat_sum(self):
#    1064     """Total likelihood given the current model parameters."""
# -> 1065     counts, npred = self.counts.data.astype(float), self.npred().data
#    1067     if self.mask is not None:
#    1068         return cash_sum_cython(counts[self.mask.data], npred[self.mask.data])
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\map.py:432, in MapDataset.npred(self)
#     424 def npred(self):
#     425     """Total predicted source and background counts
#     426
#     427     Returns
#    (...)
#     430         Total predicted counts
#     431     """
# --> 432     npred_total = self.npred_signal()
#     434     if self.background:
#     435         npred_total += self.npred_background()
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\map.py:509, in MapDataset.npred_signal(self, model_name)
#     500         evaluator.update(
#     501             self.exposure,
#     502             self.psf,
#    (...)
#     505             self.mask_image,
#     506         )
#     508     if evaluator.contributes:
# --> 509         npred = evaluator.compute_npred()
#     510         npred_total.stack(npred)
#     512 return npred_total
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\evaluator.py:382, in MapEvaluator.compute_npred(self)
#     379 if self.parameters_changed or not self.use_cache:
#     380     del self._compute_npred
# --> 382 return self._compute_npred
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\utils\decorators.py:777, in lazyproperty.__get__(self, obj, owner)
#     775         val = obj_dict.get(self._key, _NotFound)
#     776         if val is _NotFound:
# --> 777             val = self.fget(obj)
#     778             obj_dict[self._key] = val
#     779 return val
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\evaluator.py:358, in MapEvaluator._compute_npred(self)
#     356 if not self.parameter_norm_only_changed:
#     357     for method in self.methods_sequence:
# --> 358         values = method(self._computation_cache)
#     359         self._computation_cache = values
#     360     npred = self._computation_cache
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\evaluator.py:247, in MapEvaluator.compute_flux_psf_convolved(self, *arg)
#     245         value = value * self.psf_containment
#     246     else:
# --> 247         value = value * self.compute_flux_spatial()
#     249 if self.model.temporal_model:
#     250     value *= self.compute_temporal_norm()
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\evaluator.py:258, in MapEvaluator.compute_flux_spatial(self)
#     256 if self.parameters_spatial_changed() or not self.use_cache:
#     257     del self._compute_flux_spatial
# --> 258 return self._compute_flux_spatial
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\astropy\utils\decorators.py:777, in lazyproperty.__get__(self, obj, owner)
#     775         val = obj_dict.get(self._key, _NotFound)
#     776         if val is _NotFound:
# --> 777             val = self.fget(obj)
#     778             obj_dict[self._key] = val
#     779 return val
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\evaluator.py:288, in MapEvaluator._compute_flux_spatial(self)
#     286     value = (values.quantity * weights).sum(axis=(1, 2), keepdims=True)
#     287 else:
# --> 288     value = self._compute_flux_spatial_geom(self.geom)
#     290 return value
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\datasets\evaluator.py:296, in MapEvaluator._compute_flux_spatial_geom(self, geom)
#     294 if not self.model.spatial_model.is_energy_dependent:
#     295     geom = geom.to_image()
# --> 296 value = self.model.spatial_model.integrate_geom(geom)
#     298 if self.psf and self.model.apply_irf["psf"]:
#     299     value = self.apply_psf(value)
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\modeling\models\spatial.py:243, in SpatialModel.integrate_geom(self, geom, oversampling_factor)
#     241     # Finally stack result
#     242     result._unit = integrated.unit
# --> 243     result.stack(integrated)
#     244 else:
#     245     values = self.evaluate_geom(wcs_geom)
#
# File D:\Documents\Miniconda\envs\gammapy-0.20.1\lib\site-packages\gammapy\maps\wcs\ndmap.py:845, in WcsNDMap.stack(self, other, weights, nan_to_num)
#     843     cutout_slices = Ellipsis, slices[0], slices[1]
#     844 else:
# --> 845     raise ValueError(
#     846         "Can only stack equivalent maps or cutout of the same map."
#     847     )
#     849 data = other.quantity[cutout_slices].to_value(self.unit)
#     850 if nan_to_num:
#
# ValueError: Can only stack equivalent maps or cutout of the same map.

# %%
TS

# %%
result.models.parameters.to_table()

# %%
def sigma_to_ts(sigma, df=1):
    """Convert sigma to delta ts"""
    p_value = 2 * norm.sf(sigma)
    return chi2.isf(p_value, df=df)

def ts_to_sigma(ts, df=1):
    """Convert delta ts to sigma"""
    p_value = chi2.sf(ts, df=df)
    return norm.isf(0.5 * p_value)

sigma=ts_to_sigma(TS,6)
print(sigma)

# %%
dataset2 = dataset.copy()
dataset2.models = None
from gammapy.estimators import *
est = ExcessMapEstimator(correlation_radius=0.3*u.deg)
res = est.run(dataset2)
res["sqrt_ts"].plot(add_cbar=True, cmap="coolwarm")

# %%
model_simu.spatial_model.plot()

# %%
dataset2 = dataset.copy()
dataset2.models = None
from gammapy.estimators import *
est = ExcessMapEstimator(correlation_radius=0.3*u.deg)
res = est.run(dataset2)
ax = res["flux"].plot(add_cbar=True, cmap="coolwarm")
dataset.models.plot_regions(ax=ax)
model_simu.spatial_model.to_region().to_pixel(ax.wcs).plot()

# %%
dataset.npred().sum_over_axes().plot(add_cbar=True)
model_simu.spatial_model.to_region().to_pixel(ax.wcs).plot()

# %%
dataset.counts.sum_over_axes().smooth(0.04*u.deg).plot(add_cbar=True)
model_simu.spatial_model.to_region().to_pixel(ax.wcs).plot()

# %%
fpe = FluxPointsEstimator(energy_edges=energy_reco.edges, source=model.name, reoptimize=False)
flux_points = fpe.run(dataset)

# %%
ax = flux_points.plot(label="Flux points")
model.spectral_model.plot(ax=ax, energy_bounds=[0.1, 10]*u.TeV, label="fitted model", color="green")
model.spectral_model.plot_error(ax=ax, energy_bounds=[0.1, 10]*u.TeV, facecolor="green")

model_simu.spectral_model.plot(ax=ax, energy_bounds=[0.1, 10]*u.TeV, label="injected model", color="orange")
plt.legend()

# %%
print(model.parameters["sigma"].value/2)
print(model.parameters["sigma"].error/2)

# %%
print(model.parameters["amplitude"].value)
print(model.parameters["amplitude"].error)
